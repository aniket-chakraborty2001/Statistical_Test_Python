# %%
# Importing All Required Packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
# Reading the 'Report1.csv' file

report1 = pd.read_csv('Report1.csv')
report1
# Out:
#          Unnamed: 0       Mean        STD  P-Value  SignificanceLevel  \
# 0       Mathematics  33.066667   2.903255    0.080               0.05
# 1           Physics  32.816667   3.273590    0.240               0.05
# 2         Chemistry  31.083333  11.971204    0.007               0.05
# 3           Biology  29.566667  12.704811    0.005               0.05
# 4  Computer Science  30.833333  11.736221    0.010               0.05
#
#        Status
# 0      Normal
# 1      Normal
# 2  Not-Normal
# 3  Not-Normal
# 4  Not-Normal

# %%
# Reading the 'Report2.csv' file

report2 = pd.read_csv('Report2.csv')
report2
# Out:
#    Unnamed: 0       Mean        STD  P-Value  SignificanceLevel      Status
# 0     Bengali  29.133333  12.185328   0.0030               0.05  Not-Normal
# 1     English  30.250000  13.493980   0.0001               0.05  Not-Normal
# 2     History  28.950000  12.377971   0.0010               0.05  Not-Normal
# 3   Geography  28.316667  12.111278   0.0050               0.05  Not-Normal
# 4  Statistics  31.000000  11.650465   0.0010               0.05  Not-Normal

# %% [markdown]
# ## Final Result

# %%
result = pd.concat([report1, report2], axis = 0)
result
# Out:
#          Unnamed: 0       Mean        STD  P-Value  SignificanceLevel  \
# 0       Mathematics  33.066667   2.903255   0.0800               0.05
# 1           Physics  32.816667   3.273590   0.2400               0.05
# 2         Chemistry  31.083333  11.971204   0.0070               0.05
# 3           Biology  29.566667  12.704811   0.0050               0.05
# 4  Computer Science  30.833333  11.736221   0.0100               0.05
# 0           Bengali  29.133333  12.185328   0.0030               0.05
# 1           English  30.250000  13.493980   0.0001               0.05
# 2           History  28.950000  12.377971   0.0010               0.05
# 3         Geography  28.316667  12.111278   0.0050               0.05
# 4        Statistics  31.000000  11.650465   0.0010               0.05
#
#        Status
# 0      Normal
# 1      Normal
# 2  Not-Normal
# 3  Not-Normal
# 4  Not-Normal
# 0  Not-Normal
# 1  Not-Normal
# 2  Not-Normal
# 3  Not-Normal
# 4  Not-Normal
