# %%
# Importing Required Packages

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
# Reading the data named as 'StatisticalTest_Data.csv'

data = pd.read_csv('StatisticalTest_Data.csv')
data.head()
# Out:
#      Name  Maths  Physics  Chemistry  Biology  ComputerScience  Bengali  \
# 0  Aniket     37       34         24       15               48       45
# 1   Aarav     32       34         48       25               14       45
# 2   Aashi     32       34         45       40               15       23
# 3  Aayush     35       31         25       41               25       12
# 4   Aditi     26       33         45       39               48       47
#
#    English  History  Geography  Statistics Gender
# 0       15       45         45          45      M
# 1       14       12         12          12      M
# 2       45       46         13          46      F
# 3       12       48         46          12      M
# 4       14       23         48          48      F

# %%
# Getting the Entries of the Individual Columns and Storing them into variables

math = data['Maths']
phy = data['Physics']
chem = data['Chemistry']
bio = data['Biology']
cs = data['ComputerScience']
ben = data['Bengali']
eng = data['English']
his = data['History']
geo = data['Geography']
stat = data['Statistics']

# %% [markdown]
# ### Visualizing the data for the Maths Subject

# %%
# Setting the Subplot Area to plot both plots
fig = plt.figure(figsize = (10,4))
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

#Boxplot for the Maths Data
math.plot(kind = 'box',ax = ax0)
ax0.set_title('Boxplot for Maths Data')


# Histogram for Maths data
math.plot(kind = 'hist', bins = 15)
ax1.set_title('Histogram for Maths Data')
ax1.set_xlabel('Math Score')

plt.show()

# %% [markdown]
# ### Visualizing data for Physics

# %%
# Setting the Subplot Area to plot both plots
fig = plt.figure(figsize = (10,4))
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

#Boxplot for the Physics Data
phy.plot(kind = 'box',ax = ax0)
ax0.set_title('Boxplot for Physics Data')


# Histogram for Physics data
phy.plot(kind = 'hist', bins = 15)
ax1.set_title('Histogram for Physics Data')
ax1.set_xlabel('Physics Score')

plt.show()

# %% [markdown]
# ### Visualization for the Chemistry Data

# %%
# Setting the Subplot Area to plot both plots
fig = plt.figure(figsize = (10,4))
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

#Boxplot for the Chemistry Data
chem.plot(kind = 'box',ax = ax0)
ax0.set_title('Boxplot for Chemistry Data')


# Histogram for Chemistry data
chem.plot(kind = 'hist', bins = 15)
ax1.set_title('Histogram for Chemistry Data')
ax1.set_xlabel('Chemistry Score')

plt.show()

# %% [markdown]
# ### Visualization for Biology Data

# %%
# Setting the Subplot Area to plot both plots
fig = plt.figure(figsize = (10,4))
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

#Boxplot for the Biology Data
bio.plot(kind = 'box',ax = ax0)
ax0.set_title('Boxplot for Biology Data')


# Histogram for Biology data
bio.plot(kind = 'hist', bins = 15)
ax1.set_title('Histogram for Biology Data')
ax1.set_xlabel('Biology Score')

plt.show()

# %% [markdown]
# ### Visualization for ComputerScience Data

# %%
# Setting the Subplot Area to plot both plots
fig = plt.figure(figsize = (10,4))
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

#Boxplot for the Computer Science Data
cs.plot(kind = 'box',ax = ax0)
ax0.set_title('Boxplot for CS Data')


# Histogram for Computer Science data
cs.plot(kind = 'hist', bins = 15)
ax1.set_title('Histogram for ComputerScience Data')
ax1.set_xlabel('ComputerScience Score')

plt.show()
